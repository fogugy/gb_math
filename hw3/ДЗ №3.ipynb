# %%
import numpy as np
from math import exp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
# %matplotlib inline

# %% [markdown]
# #### 1. Задание (в программе)
# Нарисуйте график функции: y(x) = k∙cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
def f(x, k=1, a=0, b=0):
    return k * np.cos(x-a) + b

# %%
x = np.linspace(0, 4*np.pi, 100)
plt.plot(x,f(x), color="red");
plt.plot(x,f(x, 2, a=0.3), color="green");
plt.plot(x,f(x, 2, b=1), color="blue");
plt.grid(True)

# %% [markdown]
# #### 4.1 Задание (в программе)
# Решите систему уравнений:
# y = x**2 – 1;
# exp(x) + x∙(1 – y) = 1

# %%
x = np.append(np.linspace(-2, 0.00001, 100), np.linspace(0.00001, 3, 100))
y1 = x**2 - 1
y2 = np.exp(x)/x + 1 -1/x

plt.plot(x,y1, color="green")
plt.plot(x,y2, color="blue")
plt.grid(True)

# %%
def equations(p):
    x, y = p
    return (x**2-1-y, exp(x)+x*(1-y)-1)

x1, y1 =  fsolve(equations, (-2, -1))
x2, y2 =  fsolve(equations, (2.5, 3))

print(f'T1: {x1}, {y1}')
print(f'T2: {x2}, {y2}')
# Out:
# T1: -1.5818353529296008, 1.5022030836866855
# T2: 2.6181455730854206, 5.854686241866823
